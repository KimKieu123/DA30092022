# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

#Nhập dữ liệu
tips = sns.load_dataset('tips') #Dữ liệu tiền tip cho nhân viên tại 1 nhà hàng
display(tips)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# Matplotlib
# Vẽ biều đồ điểm trục X là số total_bill, Y là tip
#plt.scatter(tips['total_bill'], tips['tip']);
smk = pd.DataFrame(tips.loc[tips["smoker"] == "No"])
nosmk = pd.DataFrame(tips.loc[tips["smoker"] == "Yes"])
plt.scatter(smk['total_bill'], smk['tip'])
ax = plt.gac()

# %%
air = sns.load_dataset('flights') #Dữ liệu về các chuyến bay
display(air)
# Out:
#      year month  passengers
# 0    1949   Jan         112
# 1    1949   Feb         118
# 2    1949   Mar         132
# 3    1949   Apr         129
# 4    1949   May         121
# ..    ...   ...         ...
# 139  1960   Aug         606
# 140  1960   Sep         508
# 141  1960   Oct         461
# 142  1960   Nov         390
# 143  1960   Dec         432
#
# [144 rows x 3 columns]
