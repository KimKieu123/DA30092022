# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
x_ = [2,4,6,8,10]
y_ = [12.2,16.3,20.5,25.4,31.2]
data = pd.DataFrame()
data.loc[:,"x"] = pd.DataFrame(x_)
data.loc[:,"y"] = pd.DataFrame(y_)
data
#vẽ y theo x
plt.plot(data.loc[:,"x"], data.loc[:,"y"], label = "Ví dụ") #plot vẽ biểu đồ đường, nếu label = "_ ví dụ" khi có _ label sẽ ko hiển thị
plt.title("Đồ thị y theo X", fontdict={"fontsize": 18,
                                       "fontweight": 30,
                                       "color": "blue",
                                       "verticalalignment" : "baseline",
                                       "horizontalalignment" : "center"})
#horizontalalignment căn giữa
#verticalalignment căn sát
plt.xlabel("Trục X", loc = "left", fontdict={"color": "blue",
                                       "horizontalalignment" : "center"})
plt.ylabel("Trục y", fontdict={"color": "red",
                                       "horizontalalignment" : "center"})
plt.legend() #hiển thị label = "ví dụ"
#loc (location) mặc định là center, đối với trục X : left, right
#đối với trục y: top, bottom
#thay đổi cài đặ Axes, Axis
plt.plot(data.loc[:,"x"], data.loc[:,"y"])
axes1 = plt.gca() # chỉ lấy khung của plt

# %%
#chỉnh sửa bằng axes1
plt.plot(data.loc[:,"x"], data.loc[:,"y"])
axes1 = plt.gca() # chỉ lấy khung của plt
axes1.set_title("đồ thị ví dụ")
axes1.set_xlabel("trục x", color = "red", fontsize = 12)
axes1.set_ylabel("trục y", color = "red", fontsize = 12)
#thay đổi màu của spines
axes1.spines["left"].set_color("red")
axes1.spines["bottom"].set_color("green")
axes1.spines["right"].set_color("blue")
axes1.spines["top"].set_color("yellow")
#thay đổi tick
axes1.tick_params(axis = "x", color = "pink", size = 8)
axes1.tick_params(axis = "y", color = "brown", size = 8)

# %%
#BIỂU ĐỒ HIS
#X LÀ GIÁ TRỊ, Y LÀ TẦN SUẤT XUẤT HIỆN
#CUNG CẤP HÌNH DẠNG PHÂN BỔ CỦA DỮ LIỆU
#phù hợp với giá trị định lượng và các giá trị liên tục
#nếu là giá trị định danh cần rời rạc hóa dữ liệu, biêu đồ thể hiện được sẽ giống như biểu đồ hình cột
x1 = np.random.normal(size = 1000)
#plt.hist(x1, bins = 80, range = (-2,2), density = True, cumulative = True) 
plt.hist(x1, bins = 80, range = (-2,2))
#mặc định bin = 10
#range = giới hạn vùng vẽ
#rời rạc hóa dữ liệu và chia thành 80 khoảng
#density là mật độ xác xuất
#cumulative cộng dần các giá trị xác xuất
ax1 = plt.gca()
ax1.set_title("ví dụ histogram")
ax1.set_xlabel("giá trị")
ax1.set_ylabel("tần xuất")
plt.show()
